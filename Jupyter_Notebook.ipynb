# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Federico Cunese__
#
# Product Supervisor

# %% [markdown]
# _I am interested in data science because i think that understanding the processes and methodologies needed to transform data into insights is crucial to make efficient and effective business decisions_

# %% [markdown]
# ### My code shows the result of adding 1 plus 1

# %%
1+1
# Out:
# 2

# %% [markdown]
# ----------
# 1. Bananas
# 1. Apples
# 1. Milk
#
# Item  | Quantity
# ------------- | -------------
# Bananas  | 2
# Apples  | 4
# Milk  | 1
#
# ![red_apple.jpg](attachment:5dbec11e-55f3-4b51-bc78-d186e7034a6f.jpg)
